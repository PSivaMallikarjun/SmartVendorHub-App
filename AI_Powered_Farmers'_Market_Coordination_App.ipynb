# %% [markdown]
# <a href="https://colab.research.google.com/github/PSivaMallikarjun/SmartVendorHub-App/blob/main/AI_Powered_Farmers'_Market_Coordination_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI-Powered Farmers' Market Coordination App

# %% [markdown]
# A **Detailed Project Report (DPR)** for the AI-Powered Farmers' Market Coordination App. The DPR outlines the overall plan, objectives, technical architecture, key features, and business benefits of the system.
#
# ---
#
# # **Detailed Project Report (DPR)**
# ## **AI-Powered Farmers' Market Coordination App**
#
# ### **Project Overview**
#
# The AI-Powered Farmers' Market Coordination App aims to solve the challenges faced by consumers, farmers, and vendors in urban markets, specifically focusing on food wastage, price fluctuations, market accessibility, and transparency in the supply chain. The app facilitates communication between consumers, farmers, and vendors, streamlining the procurement and booking processes, ensuring a smooth and efficient transaction process.
#
# ---
#
# ### **1. Introduction**
#
# #### **1.1 Problem Statement**
# - Consumers face challenges in accessing fresh, quality food at fair prices.
# - Farmers are unable to accurately predict demand, leading to food wastage and losses.
# - Overpricing and fluctuating food prices are prevalent in the market.
# - Lack of transparency in food sourcing, quality grading, and availability.
# - Limited access to digital tools for pre-booking and real-time market visibility.
#
# #### **1.2 Project Objectives**
# - To create an AI-driven platform that connects consumers, farmers, and vendors in a transparent, efficient, and easy-to-use environment.
# - To enable consumers to pre-book food items a week in advance and ensure a seamless transaction process.
# - To help farmers and vendors manage their stock and availability based on demand forecasting and real-time updates.
# - To minimize food wastage, ensure fair pricing, and improve market transparency.
#
# ---
#
# ### **2. Scope of Work**
#
# #### **2.1 Functional Scope**
# - **Consumer Interface**:
#   - Consumers can view the availability of food items based on demand forecasts.
#   - They can pre-book items without paying immediately and complete the transaction during market hours.
#   - Access to quality information on food items (e.g., organic, pesticide-free).
#   - Option for digital payments.
#
# - **Farmer and Vendor Interface**:
#   - Farmers can list their available items along with quality details and availability dates.
#   - Farmers can view consumer demands and fulfill them, ensuring better planning.
#   - Real-time updates on stock availability and demand fulfillment.
#
# - **AI Agent**:
#   - AI agent forecasts demand based on consumer requests and market trends.
#   - It helps farmers understand demand patterns and adjust their stock.
#   - Provides price prediction models based on historical data.
#
# - **Admin Panel**:
#   - Admin will manage the entire platform, monitor transactions, resolve disputes, and ensure compliance with market standards.
#
# ---
#
# ### **3. Technical Architecture**
#
# #### **3.1 System Design**
#
# - **Frontend**:
#   - Built using **Gradio UI**, providing a simple, interactive user interface for both consumers and vendors.
#
# - **Backend**:
#   - Powered by **DuckDB** for data storage and management, ensuring fast queries for real-time updates.
#   - **Python** for logic implementation, AI agent, and data manipulation.
#   - **Machine Learning Models** (including Reinforcement Learning, Neural Networks, and Demand Forecasting) for predicting demand and ensuring optimal supply chain management.
#
# - **AI Components**:
#   - **Reinforcement Learning (RL)** to continuously adapt the system based on past consumer behavior and market conditions.
#   - **OCR** and **NER** for extracting relevant data from textual sources like farmer stock lists and consumer requests.
#   - **Deep Learning (DL)** models, including **CNN**, for processing image data (e.g., quality grading of food items).
#
# #### **3.2 Data Flow**
#
# 1. **Consumer Request**: Consumers input their food requirements, including quantity and quality.
# 2. **Demand Forecasting**: AI agent uses historical data and trends to predict market demand.
# 3. **Farmer Stock Listing**: Farmers enter the availability of their produce along with quality grading.
# 4. **Pre-booking Process**: Consumers can pre-book items without paying upfront.
# 5. **Payment and Pickup**: Consumers pay and collect the pre-booked items on market day.
# 6. **Real-time Updates**: The system constantly updates based on new stock inputs, consumer requests, and AI predictions.
#
# ---
#
# ### **4. Key Features**
#
# #### **4.1 Consumer Features**
# - **Pre-booking**: Consumers can pre-book vegetables and fruits a week in advance.
# - **Real-Time Stock Availability**: View the current availability of products based on predictions and real-time input from farmers.
# - **Quality Assurance**: Access quality grades of food (e.g., organic, fresh, pesticide-free).
# - **Digital Payment**: Secure payment gateway for digital transactions.
# - **Delivery/Takeaway Option**: Consumers can choose to pick up the items directly from the vendor.
#
# #### **4.2 Vendor/Farmer Features**
# - **Stock Management**: Farmers can list their available stock, with details about quality, availability dates, and prices.
# - **Demand Insights**: Farmers can view consumer demands and adjust their stock accordingly.
# - **Pre-booking Management**: Handle pre-booking requests, ensuring stock is reserved for consumers.
# - **Earnings and Payments**: Manage earnings and track payments made by consumers.
#
# #### **4.3 AI Features**
# - **Demand Forecasting**: AI predicts the market demand for various food items based on consumer requests and historical data.
# - **Price Prediction**: Predicts the prices of items based on market trends and surplus/shortage conditions.
# - **Optimization Algorithms**: Helps farmers optimize their stock production and reduce waste by suggesting demand-driven stock adjustments.
#
# ---
#
# ### **5. Business Model**
#
# - **Revenue Generation**:
#   - **Brokerage Fee**: The app collects a minimal fee (0.8% to 1.5%) on every transaction made through pre-bookings.
#   - **Subscription Model for Farmers**: Farmers may subscribe to premium features for enhanced visibility, stock analytics, and demand forecasting.
#
# - **Cost Structure**:
#   - **Development and Maintenance Costs**: Continuous updates to the AI models, backend, and frontend.
#   - **Server and Cloud Hosting**: Costs associated with cloud services for hosting the app and database.
#   - **Marketing and Outreach**: Costs for acquiring new farmers and consumers, including ads and promotions.
#
# ---
#
# ### **6. Market Analysis**
#
# #### **6.1 Target Market**
# - **Urban Consumers**: Focused on individuals who prefer fresh, organic food and who are conscious about food quality and pricing.
# - **Farmers and Vendors**: Small-scale farmers, cooperative societies, and local vendors looking to streamline their sales processes and increase visibility.
#
# #### **6.2 Competitive Analysis**
# - **Current Market Solutions**: Many e-commerce platforms exist for food delivery, but they lack the local connection between farmers and consumers and often include high margins.
# - **Unique Selling Proposition (USP)**: The app's USP lies in direct farmer-to-consumer interaction, AI-driven demand forecasting, and real-time market stock management.
#
# ---
#
# ### **7. Implementation Plan**
#
# #### **7.1 Phases of Implementation**
# - **Phase 1: Design and Development** (1-3 months)
#   - Develop the app's frontend and backend.
#   - Build machine learning models and set up the database.
#   - Create initial UI/UX for farmers and consumers.
#
# - **Phase 2: Pilot Testing** (3-6 months)
#   - Conduct a pilot test in a small region.
#   - Collect feedback from users and make necessary adjustments.
#   - Train farmers and vendors on using the platform.
#
# - **Phase 3: Full Launch** (6-12 months)
#   - Scale the system to multiple regions.
#   - Expand the marketing efforts and onboard more farmers and consumers.
#   - Continuously improve the system based on user feedback and data insights.
#
# ---
#
# ### **8. Monitoring and Evaluation**
#
# - **User Feedback**: Collect regular feedback from farmers, vendors, and consumers to improve the platform.
# - **AI Performance**: Continuously monitor AI prediction accuracy and demand forecasting models.
# - **System Performance**: Track app uptime, transaction success rates, and overall user satisfaction.
#
# ---
#
# ### **9. Conclusion**
#
# The **AI-Powered Farmers' Market Coordination App** presents a transformative solution to modernize the agricultural supply chain. By enabling transparent communication between consumers, farmers, and vendors, the app addresses key challenges such as food wastage, fluctuating prices, and market inefficiencies. The integration of AI ensures that the supply chain is optimized, benefiting all stakeholders—especially the farmers who get better visibility and fair compensation for their produce.
#
# This project has the potential to revolutionize the agricultural market by creating a community-driven, demand-forecasting ecosystem that brings the power of technology to the forefront of food distribution.
#
# ---
#
# **End of DPR**
#
# This is a high-level draft of your Detailed Project Report (DPR) for your AI-Powered Farmers' Market Coordination App. It covers all the important sections from problem definition to the market analysis, implementation plan, and business model.

# %%
# !pip install google-adk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.1/232.1 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.1/334.1 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# !pip install Gradio
# !pip install pytesseract
# !pip install spacy
# !pip install tensorflow
# !pip install keras
# !pip install sqlite3
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/groovy/
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 104.1 MB/s eta 0:00:00
# ...
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
# !pip install duckdb

# %%
# !pip install pandas

# %%
# !pip install datetime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 10.2 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import duckdb
import pandas as pd
from datetime import datetime

# Connect to DuckDB
db_path = "market_ai_duckdb.db"
conn = duckdb.connect(db_path)

# Create Tables
conn.execute("""
CREATE TABLE IF NOT EXISTS consumer_requests (
    id INTEGER,
    consumer_name VARCHAR,
    item_name VARCHAR,
    requested_qty INTEGER,
    unit VARCHAR,
    required_date VARCHAR
);
""")

conn.execute("""
CREATE TABLE IF NOT EXISTS farmer_stock (
    id INTEGER,
    farmer_name VARCHAR,
    item_name VARCHAR,
    available_qty INTEGER,
    unit VARCHAR,
    quality_grade VARCHAR,
    available_date VARCHAR
);
""")

# Consumer submission
def submit_consumer(consumer_name, item_name, requested_qty, unit, required_date):
    conn.execute("""
        INSERT INTO consumer_requests VALUES (?, ?, ?, ?, ?, ?);
    """, (int(datetime.now().timestamp()), consumer_name, item_name, requested_qty, unit, required_date))
    return "Consumer request submitted successfully."

# Farmer submission
def submit_farmer(farmer_name, item_name, available_qty, unit, quality_grade, available_date):
    conn.execute("""
        INSERT INTO farmer_stock VALUES (?, ?, ?, ?, ?, ?, ?);
    """, (int(datetime.now().timestamp()), farmer_name, item_name, available_qty, unit, quality_grade, available_date))
    return "Farmer stock submitted successfully."

# Market Match Display
def view_market_matches():
    query = """
        SELECT c.consumer_name, c.item_name, c.requested_qty, c.unit AS consumer_unit, c.required_date,
               f.farmer_name, f.available_qty, f.unit AS farmer_unit, f.quality_grade, f.available_date
        FROM consumer_requests c
        LEFT JOIN farmer_stock f ON c.item_name = f.item_name AND c.unit = f.unit
        WHERE c.required_date <= f.available_date
    """
    df = conn.execute(query).df()
    return df

# Pre-booking simulation
def pre_book_item(consumer_name, item_name):
    return f"{consumer_name} pre-booked {item_name}. Please proceed to checkout during market day."

# Consumer Interface
consumer_interface = gr.Interface(
    fn=submit_consumer,
    inputs=[
        gr.Text(label="Consumer Name"),
        gr.Text(label="Item Name"),
        gr.Number(label="Quantity Required"),
        gr.Text(label="Unit (e.g., kg, liters)"),
        gr.Text(label="Required Date (YYYY-MM-DD)")
    ],
    outputs="text",
    title="Consumer Request Submission",
    description="Enter your food item requirement for the upcoming week."
)

# Farmer Interface
farmer_interface = gr.Interface(
    fn=submit_farmer,
    inputs=[
        gr.Text(label="Farmer Name"),
        gr.Text(label="Item Name"),
        gr.Number(label="Available Quantity"),
        gr.Text(label="Unit (e.g., kg, liters)"),
        gr.Text(label="Quality Grade"),
        gr.Text(label="Available Date (YYYY-MM-DD)")
    ],
    outputs="text",
    title="Farmer Stock Availability Submission",
    description="Enter the available food item details for next week's market."
)

# Dashboard View Interface
match_interface = gr.Interface(
    fn=view_market_matches,
    inputs=[],
    outputs=gr.Dataframe(headers=[
        "consumer_name", "item_name", "requested_qty", "consumer_unit",
        "required_date", "farmer_name", "available_qty", "farmer_unit",
        "quality_grade", "available_date"
    ]),
    title="Market Dashboard",
    description="Market Matches: Consumer Demand vs Farmer Stock"
)

# Pre-booking tab
prebook_interface = gr.Interface(
    fn=pre_book_item,
    inputs=[
        gr.Text(label="Consumer Name"),
        gr.Text(label="Item Name")
    ],
    outputs="text",
    title="Pre-Booking Portal",
    description="Pre-book your selected item."
)

# Launch Tabs
gr.TabbedInterface(
    interface_list=[consumer_interface, farmer_interface, match_interface, prebook_interface],
    tab_names=["Consumer Request", "Farmer Stock", "Market Matches", "Pre-Booking"]
).launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://956ac37110914614b2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://956ac37110914614b2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install gradio
# !pip install pytesseract
# !pip install spacy
# !pip install tensorflow
# !pip install keras
# !pip install sqlite3
# !pip install duckdb
# !pip install pandas
# !pip install datetime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 69.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 4.2 MB/s eta 0:00:00
# ...
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 8.9 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import duckdb
import pandas as pd
from datetime import datetime
import random

# --- MCP Registry ---
class MCP:
    def __init__(self):
        self.agents = {}
        self.services = {}  # To map service types to agent names

    def register_agent(self, name, agent, services=None):
        self.agents[name] = agent
        if services:
            for service in services:
                if service not in self.services:
                    self.services[service] = []
                self.services[service].append(name)

    def get_agent(self, name):
        return self.agents.get(name)

    def find_agents_by_service(self, service_type):
        return self.services.get(service_type, [])

mcp_registry = MCP()

# --- Data Management Agent ---
class DataManagementAgent:
    def __init__(self, db_path="market_ai_duckdb.db"):
        self.conn = duckdb.connect(db_path)
        self._create_tables()

    def _create_tables(self):
        # ... (table creation SQL from your code) ...
        try:
            self.conn.execute("""
            CREATE TABLE IF NOT EXISTS demand_forecasts (
                item_name VARCHAR,
                location VARCHAR,
                forecast_date VARCHAR,
                predicted_demand INTEGER
            );
            """)
        except Exception as e:
            print(f"Error creating demand_forecasts table: {e}")

        try:
            self.conn.execute("""
            CREATE TABLE IF NOT EXISTS consumer_requests (
                id INTEGER,
                consumer_name VARCHAR,
                item_name VARCHAR,
                requested_qty INTEGER,
                unit VARCHAR,
                required_date VARCHAR
            );
            """)
        except Exception as e:
            print(f"Error creating consumer_requests table: {e}")

        try:
            self.conn.execute("""
            CREATE TABLE IF NOT EXISTS farmer_stock (
                id INTEGER,
                farmer_name VARCHAR,
                item_name VARCHAR,
                available_qty INTEGER,
                unit VARCHAR,
                quality_grade VARCHAR,
                available_date VARCHAR
            );
            """)
        except Exception as e:
            print(f"Error creating farmer_stock table: {e}")
        self.conn.commit()


    def insert(self, table_name, data):
        cursor = self.conn.cursor()
        placeholders = ', '.join(['?'] * len(data))
        query = f"INSERT INTO {table_name} VALUES ({placeholders})"
        try:
            cursor.execute(query, data)
            self.conn.commit()
        except Exception as e:
            print(f"Error inserting into {table_name}: {e}")

    def fetch(self, query):
        try:
            df = self.conn.execute(query).df()
            return df
        except Exception as e:
            print(f"Error fetching data: {e}")
            return pd.DataFrame()

data_agent = DataManagementAgent()
mcp_registry.register_agent("data_agent", data_agent, services=["data_storage"])

# --- Demand Forecasting Agent (Simplified) ---
class DemandForecastingAgent:
    def __init__(self, data_agent):
        self.data_agent = data_agent

    def predict_demand(self, item_name, location, forecast_date):
        # In a real scenario, this would involve ML models
        # For this example, we'll return a random forecast
        predicted_demand = random.randint(10, 100)
        self.data_agent.insert("demand_forecasts", (item_name, location, forecast_date, predicted_demand))
        return f"Predicted demand for {item_name} in {location} on {forecast_date}: {predicted_demand}"

demand_forecaster = DemandForecastingAgent(data_agent)
mcp_registry.register_agent("demand_forecaster", demand_forecaster, services=["demand_forecasting"])

# --- Vendor Agent (Illustrative) ---
class VendorAgent:
    def __init__(self, mcp_registry):
        self.mcp_registry = mcp_registry

    def get_demand_forecast(self, item_name, location, forecast_date):
        forecasting_agents = self.mcp_registry.find_agents_by_service("demand_forecasting")
        if forecasting_agents:
            # For simplicity, we'll use the first available forecasting agent
            forecaster_name = forecasting_agents[0]
            forecaster = self.mcp_registry.get_agent(forecaster_name)
            return forecaster.predict_demand(item_name, location, forecast_date)
        else:
            return "No demand forecasting agent available."

vendor_agent = VendorAgent(mcp_registry)
mcp_registry.register_agent("vendor_agent", vendor_agent)

# --- Consumer Agent ---
class ConsumerAgent:
    def __init__(self, data_agent):
        self.data_agent = data_agent

    def submit_request(self, consumer_name, item_name, requested_qty, unit, required_date):
        data = (int(datetime.now().timestamp()), consumer_name, item_name, requested_qty, unit, required_date)
        self.data_agent.insert("consumer_requests", data)
        return "Consumer request submitted successfully."

consumer_agent = ConsumerAgent(data_agent)
mcp_registry.register_agent("consumer_agent", consumer_agent, services=["consumer_request_submission"])

# --- Farmer Agent ---
class FarmerAgent:
    def __init__(self, data_agent):
        self.data_agent = data_agent

    def submit_stock(self, farmer_name, item_name, available_qty, unit, quality_grade, available_date):
        data = (int(datetime.now().timestamp()), farmer_name, item_name, available_qty, unit, quality_grade, available_date)
        self.data_agent.insert("farmer_stock", data)
        return "Farmer stock submitted successfully."

farmer_agent = FarmerAgent(data_agent)
mcp_registry.register_agent("farmer_agent", farmer_agent, services=["farmer_stock_submission"])

# --- Matching Agent ---
class MatchingAgent:
    def __init__(self, data_agent):
        self.data_agent = data_agent

    def view_matches(self):
        query = """
            SELECT c.consumer_name, c.item_name, c.requested_qty, c.unit AS consumer_unit, c.required_date,
                   f.farmer_name, f.available_qty, f.unit AS farmer_unit, f.quality_grade, f.available_date
            FROM consumer_requests c
            LEFT JOIN farmer_stock f ON c.item_name = f.item_name AND c.unit = f.unit
            WHERE c.required_date <= f.available_date
        """
        df = self.data_agent.fetch(query)
        return df

matching_agent = MatchingAgent(data_agent)
mcp_registry.register_agent("matching_agent", matching_agent, services=["market_matching"])

# --- Pre-Booking Agent ---
class PreBookingAgent:
    def pre_book_item(self, consumer_name, item_name):
        return f"{consumer_name} pre-booked {item_name}. Please proceed to checkout during market day."

prebooking_agent = PreBookingAgent()
mcp_registry.register_agent("prebooking_agent", prebooking_agent, services=["pre_booking"])

# --- GRADIO UI ---
def submit_consumer_ui(consumer_name, item_name, requested_qty, unit, required_date):
    agent = mcp_registry.get_agent("consumer_agent")
    return agent.submit_request(consumer_name, item_name, requested_qty, unit, required_date)

def submit_farmer_ui(farmer_name, item_name, available_qty, unit, quality_grade, available_date):
    agent = mcp_registry.get_agent("farmer_agent")
    return agent.submit_stock(farmer_name, item_name, available_qty, unit, quality_grade, available_date)

def view_market_matches_ui():
    agent = mcp_registry.get_agent("matching_agent")
    return agent.view_matches()

def pre_book_item_ui(consumer_name, item_name):
    agent = mcp_registry.get_agent("prebooking_agent")
    return agent.pre_book_item(consumer_name, item_name)

def get_demand_forecast_ui(item_name, location, forecast_date):
    vendor = mcp_registry.get_agent("vendor_agent")
    return vendor.get_demand_forecast(item_name, location, forecast_date)

with gr.Blocks() as app:
    gr.Markdown("## Agentic AI Market App with MCP")

    with gr.Tab("Consumer Request"):
        uid = gr.Textbox(label="Consumer Name")
        item = gr.Textbox(label="Item Name")
        qty = gr.Number(label="Quantity Required")
        unit = gr.Textbox(label="Unit (e.g., kg, liters)")
        req_date = gr.Textbox(label="Required Date (YYYY-MM-DD)")
        consumer_btn = gr.Button("Submit Request")
        consumer_output = gr.Textbox()
        consumer_btn.click(submit_consumer_ui, inputs=[uid, item, qty, unit, req_date], outputs=consumer_output)

    with gr.Tab("Farmer Stock"):
        fid = gr.Textbox(label="Farmer Name")
        item_stock = gr.Textbox(label="Item Name")
        qty_stock = gr.Number(label="Available Quantity")
        unit_stock = gr.Textbox(label="Unit (e.g., kg, liters)")
        quality = gr.Textbox(label="Quality Grade")
        avail_date = gr.Textbox(label="Available Date (YYYY-MM-DD)")
        farmer_btn = gr.Button("Submit Stock")
        farmer_output = gr.Textbox()
        farmer_btn.click(submit_farmer_ui, inputs=[fid, item_stock, qty_stock, unit_stock, quality, avail_date], outputs=farmer_output)

    with gr.Tab("Market Matches"):
        match_btn = gr.Button("View Matches")
        match_output = gr.Dataframe()
        match_btn.click(view_market_matches_ui, outputs=match_output)

    with gr.Tab("Pre-Booking"):
        consumer_name_prebook = gr.Textbox(label="Consumer Name")
        item_name_prebook = gr.Textbox(label="Item Name")
        prebook_btn = gr.Button("Pre-Book Item")
        prebook_output = gr.Textbox()
        prebook_btn.click(pre_book_item_ui, inputs=[consumer_name_prebook, item_name_prebook], outputs=prebook_output)

    with gr.Tab("Vendor Services"):
        item_forecast = gr.Textbox(label="Item Name")
        location_forecast = gr.Textbox(label="Location")
        date_forecast = gr.Textbox(label="Forecast Date (YYYY-MM-DD)")
        forecast_btn = gr.Button("Get Demand Forecast")
        forecast_output = gr.Textbox()
        forecast_btn.click(get_demand_forecast_ui, inputs=[item_forecast, location_forecast, date_forecast], outputs=forecast_output)

app.launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9bc2b2175187a861d1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9bc2b2175187a861d1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # These are the Functional results of app

# %% [markdown]
# ![Screenshot 2025-04-16 225029.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-16 225149.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-16 225156.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-16 225209.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-16 225244.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-16 225410.png](data:image/png;base64,...)

# %% [markdown]
# Imagine a really busy street market in India. There are lots of vendors selling fruits, vegetables, snacks, etc., and many people trying to buy. Here's how this app, with all its smart "agents," can make things easier:
#
# **For the Street Vendor:**
#
# * **Knowing what to sell:** Imagine a vegetable vendor. Sometimes they buy too many tomatoes and they spoil because not enough people bought them. This app has a "smart guesser" (the **Demand Forecasting Agent**) that looks at things like past sales, if it's going to rain, or if there's a festival coming up, and tells the vendor, "Hey, people will probably want more onions this week, and maybe fewer carrots." This helps the vendor buy the right amount and avoid waste.
# * **Selling good stuff:** A vendor wants to sell fresh vegetables. If they're buying from a big supplier, they might not always know the quality. This app could have a "quality checker" (**Quality Assessment Agent**) where the vendor can take a picture of the vegetables, and the app can say, "These look pretty good!" or "Maybe these are starting to get old." This helps the vendor sell better quality items.
# * **Setting the right price:** Sometimes vendors don't know if they're charging too much or too little. The app has a "price helper" (**Price Optimization Agent**) that looks at how much other vendors are charging, how much demand there is, and how much stock the vendor has, and suggests a price that's fair for everyone.
# * **Getting supplies easily:** A vendor might struggle to find the best place to buy their vegetables. The app could have a "supply finder" (**Logistics and Supply Chain Agent**) that helps them connect with farmers or wholesalers who have good quality produce at good prices.
# * **Helping customers:** If a customer asks if they have a certain type of mango, the vendor might be busy. The app could have a "customer helper" (**Customer Service Agent**) that can answer basic questions for the vendor.
# * **Taking payments easily:** Instead of just cash, the app could let customers pay using their phone (like UPI) through a "**Payment Processing Agent**," which is safer and more convenient.
# * **Knowing the rules:** There are often rules about where vendors can sell and how they should keep things clean. The app could have a "**Regulatory Compliance Agent**" that gives vendors this important information.
#
# **For the Person Buying (the Customer):**
#
# * **Finding fresh stuff:** Customers want to buy good, fresh food. If the vendor is using the "quality checker" on the app, the customer has a better chance of getting good quality items.
# * **Paying a fair price:** The "price helper" on the app can help keep prices fair, so customers don't get overcharged.
# * **Buying quickly:** Imagine a busy market. Customers want to buy and leave quickly. The app could let them see what vendors have in stock beforehand.
# * **Getting what they want:** If a customer knows they need a specific vegetable, they might be able to use the app to see which vendors are likely to have it.
# * **Paying easily:** Paying with their phone through the app is much easier than carrying lots of cash.
# * **Knowing where to go:** If a customer has a favorite vendor, the app might help them find that vendor in the market.
# * **Maybe even ordering ahead:** In the future, the app could even let customers pre-book what they need so it's ready for them when they arrive.
#
# **Think of the "agents" as different smart tools within the app.** The "MCP" is like a central hub where all these tools can talk to each other and work together to make the whole market experience smoother and better for both the sellers and the buyers. It's like having a little smart assistant in your pocket for the market!
